# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
# %matplotlib inline
import seaborn as sns
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
df=pd.read_csv('file:///C:/Users/mdasi/Downloads/Compressed/smoking.csv/smoking.csv')
df.head()
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60       81.3             1.2
# 1   1      F   40         160          60       81.0             0.8
# 2   2      M   55         170          60       80.0             0.8
# 3   3      M   40         165          70       88.0             1.5
# 4   4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              1.0            1.0             1.0  ...        12.9
# 1              0.6            1.0             1.0  ...        12.7
# 2              0.8            1.0             1.0  ...        15.8
# 3              1.5            1.0             1.0  ...        14.7
# 4              1.0            1.0             1.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               0.7  18.0  19.0  27.0     Y              0
# 1            1.0               0.6  22.0  19.0  18.0     Y              0
# 2            1.0               1.0  21.0  16.0  22.0     Y              0
# 3            1.0               1.0  19.0  26.0  18.0     Y              0
# 4            1.0               0.6  16.0  14.0  22.0     Y              0
#
#    tartar  smoking
# 0       Y        0
# 1       Y        0
# 2       N        1
# 3       Y        0
# 4       N        0
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (55692, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55692 entries, 0 to 55691
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   55692 non-null  int64
#  1   gender               55692 non-null  object
#  2   age                  55692 non-null  int64
#  3   height(cm)           55692 non-null  int64
#  4   weight(kg)           55692 non-null  int64
#  5   waist(cm)            55692 non-null  float64
#  6   eyesight(left)       55692 non-null  float64
#  7   eyesight(right)      55692 non-null  float64
#  8   hearing(left)        55692 non-null  float64
#  9   hearing(right)       55692 non-null  float64
#  10  systolic             55692 non-null  float64
#  11  relaxation           55692 non-null  float64
#  12  fasting blood sugar  55692 non-null  float64
#  13  Cholesterol          55692 non-null  float64
#  14  triglyceride         55692 non-null  float64
#  15  HDL                  55692 non-null  float64
#  16  LDL                  55692 non-null  float64
#  17  hemoglobin           55692 non-null  float64
#  18  Urine protein        55692 non-null  float64
#  19  serum creatinine     55692 non-null  float64
#  20  AST                  55692 non-null  float64
#  21  ALT                  55692 non-null  float64
#  22  Gtp                  55692 non-null  float64
#  23  oral                 55692 non-null  object
#  24  dental caries        55692 non-null  int64
#  25  tartar               55692 non-null  object
#  26  smoking              55692 non-null  int64
# dtypes: float64(18), int64(6), object(3)
# memory usage: 11.5+ MB

# %%
df.dtypes
# Out:
# ID                       int64
# gender                  object
# age                      int64
# height(cm)               int64
# weight(kg)               int64
# waist(cm)              float64
# eyesight(left)         float64
# eyesight(right)        float64
# hearing(left)          float64
# hearing(right)         float64
# systolic               float64
# relaxation             float64
# fasting blood sugar    float64
# Cholesterol            float64
# triglyceride           float64
# HDL                    float64
# LDL                    float64
# hemoglobin             float64
# Urine protein          float64
# serum creatinine       float64
# AST                    float64
# ALT                    float64
# Gtp                    float64
# oral                    object
# dental caries            int64
# tartar                  object
# smoking                  int64
# dtype: object

# %%
df.describe()
# Out:
#                  ID           age    height(cm)    weight(kg)     waist(cm)  \
# count  55692.000000  55692.000000  55692.000000  55692.000000  55692.000000
# mean   27845.500000     44.182917    164.649321     65.864936     82.046418
# std    16077.039933     12.071418      9.194597     12.820306      9.274223
# min        0.000000     20.000000    130.000000     30.000000     51.000000
# 25%    13922.750000     40.000000    160.000000     55.000000     76.000000
# 50%    27845.500000     40.000000    165.000000     65.000000     82.000000
# 75%    41768.250000     55.000000    170.000000     75.000000     88.000000
# max    55691.000000     85.000000    190.000000    135.000000    129.000000
#
#        eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# count    55692.000000     55692.000000   55692.000000    55692.000000
# mean         1.012623         1.007443       1.025587        1.026144
# std          0.486873         0.485964       0.157902        0.159564
# min          0.100000         0.100000       1.000000        1.000000
# 25%          0.800000         0.800000       1.000000        1.000000
# 50%          1.000000         1.000000       1.000000        1.000000
# 75%          1.200000         1.200000       1.000000        1.000000
# max          9.900000         9.900000       2.000000        2.000000
#
#            systolic  ...           HDL           LDL    hemoglobin  \
# count  55692.000000  ...  55692.000000  55692.000000  55692.000000
# mean     121.494218  ...     57.290347    114.964501     14.622592
# std       13.675989  ...     14.738963     40.926476      1.564498
# min       71.000000  ...      4.000000      1.000000      4.900000
# 25%      112.000000  ...     47.000000     92.000000     13.600000
# 50%      120.000000  ...     55.000000    113.000000     14.800000
# 75%      130.000000  ...     66.000000    136.000000     15.800000
# max      240.000000  ...    618.000000   1860.000000     21.100000
#
#        Urine protein  serum creatinine           AST           ALT  \
# count   55692.000000      55692.000000  55692.000000  55692.000000
# mean        1.087212          0.885738     26.182935     27.036037
# std         0.404882          0.221524     19.355460     30.947853
# min         1.000000          0.100000      6.000000      1.000000
# 25%         1.000000          0.800000     19.000000     15.000000
# 50%         1.000000          0.900000     23.000000     21.000000
# 75%         1.000000          1.000000     28.000000     31.000000
# max         6.000000         11.600000   1311.000000   2914.000000
#
#                 Gtp  dental caries       smoking
# count  55692.000000   55692.000000  55692.000000
# mean      39.952201       0.213334      0.367288
# std       50.290539       0.409665      0.482070
# min        1.000000       0.000000      0.000000
# 25%       17.000000       0.000000      0.000000
# 50%       25.000000       0.000000      0.000000
# 75%       43.000000       0.000000      1.000000
# max      999.000000       1.000000      1.000000
#
# [8 rows x 24 columns]

# %%
df.describe().corr().T
# Out:
#                            ID       age  height(cm)  weight(kg)  waist(cm)  \
# ID                   1.000000  0.520982    0.521340    0.521493   0.521244
# age                  0.520982  1.000000    0.999998    1.000000   1.000000
# height(cm)           0.521340  0.999998    1.000000    0.999998   0.999999
# weight(kg)           0.521493  1.000000    0.999998    1.000000   1.000000
# waist(cm)            0.521244  1.000000    0.999999    1.000000   1.000000
# eyesight(left)       0.520230  1.000000    0.999996    0.999999   0.999999
# eyesight(right)      0.520230  1.000000    0.999996    0.999999   0.999999
# hearing(left)        0.520137  0.999999    0.999996    0.999998   0.999999
# hearing(right)       0.520137  0.999999    0.999996    0.999998   0.999999
# systolic             0.522350  0.999998    0.999998    0.999999   0.999999
# relaxation           0.521514  1.000000    0.999999    1.000000   1.000000
# fasting blood sugar  0.525310  0.999977    0.999977    0.999981   0.999979
# Cholesterol          0.524944  0.999986    0.999989    0.999990   0.999989
# triglyceride         0.531139  0.999881    0.999881    0.999891   0.999885
# HDL                  0.526847  0.999956    0.999955    0.999961   0.999958
# LDL                  0.540164  0.999522    0.999525    0.999541   0.999530
# hemoglobin           0.520343  1.000000    0.999997    0.999999   0.999999
# Urine protein        0.520179  0.999999    0.999996    0.999998   0.999999
# serum creatinine     0.520248  1.000000    0.999996    0.999999   0.999999
# AST                  0.534002  0.999755    0.999754    0.999768   0.999760
# ALT                  0.550745  0.998705    0.998708    0.998736   0.998718
# Gtp                  0.530752  0.999865    0.999863    0.999875   0.999868
# dental caries        0.520132  0.999999    0.999996    0.999998   0.999999
# smoking              0.520138  0.999999    0.999996    0.999998   0.999999
#
#                      eyesight(left)  eyesight(right)  hearing(left)  \
# ID                         0.520230         0.520230       0.520137
# age                        1.000000         1.000000       0.999999
# height(cm)                 0.999996         0.999996       0.999996
# weight(kg)                 0.999999         0.999999       0.999998
# waist(cm)                  0.999999         0.999999       0.999999
# eyesight(left)             1.000000         1.000000       1.000000
# eyesight(right)            1.000000         1.000000       1.000000
# hearing(left)              1.000000         1.000000       1.000000
# hearing(right)             1.000000         1.000000       1.000000
# systolic                   0.999995         0.999995       0.999995
# relaxation                 0.999998         0.999998       0.999998
# fasting blood sugar        0.999971         0.999971       0.999970
# Cholesterol                0.999981         0.999981       0.999980
# triglyceride               0.999869         0.999869       0.999867
# HDL                        0.999948         0.999948       0.999947
# LDL                        0.999498         0.999498       0.999494
# hemoglobin                 1.000000         1.000000       1.000000
# Urine protein              1.000000         1.000000       1.000000
# serum creatinine           1.000000         1.000000       1.000000
# AST                        0.999739         0.999739       0.999735
# ALT                        0.998668         0.998668       0.998661
# Gtp                        0.999853         0.999853       0.999851
# dental caries              1.000000         1.000000       1.000000
# smoking                    1.000000         1.000000       1.000000
#
#                      hearing(right)  systolic  ...       HDL       LDL  \
# ID                         0.520137  0.522350  ...  0.526847  0.540164
# age                        0.999999  0.999998  ...  0.999956  0.999522
# height(cm)                 0.999996  0.999998  ...  0.999955  0.999525
# weight(kg)                 0.999998  0.999999  ...  0.999961  0.999541
# waist(cm)                  0.999999  0.999999  ...  0.999958  0.999530
# eyesight(left)             1.000000  0.999995  ...  0.999948  0.999498
# eyesight(right)            1.000000  0.999995  ...  0.999948  0.999498
# hearing(left)              1.000000  0.999995  ...  0.999947  0.999494
# hearing(right)             1.000000  0.999995  ...  0.999947  0.999494
# systolic                   0.999995  1.000000  ...  0.999970  0.999573
# relaxation                 0.999998  0.999999  ...  0.999962  0.999543
# fasting blood sugar        0.999970  0.999987  ...  0.999996  0.999709
# Cholesterol                0.999980  0.999995  ...  0.999985  0.999650
# triglyceride               0.999867  0.999906  ...  0.999982  0.999878
# HDL                        0.999947  0.999970  ...  1.000000  0.999769
# LDL                        0.999494  0.999573  ...  0.999769  1.000000
# hemoglobin                 1.000000  0.999996  ...  0.999949  0.999499
# Urine protein              1.000000  0.999995  ...  0.999947  0.999496
# serum creatinine           1.000000  0.999995  ...  0.999949  0.999499
# AST                        0.999735  0.999790  ...  0.999919  0.999960
# ALT                        0.998661  0.998789  ...  0.999139  0.999798
# Gtp                        0.999851  0.999890  ...  0.999975  0.999893
# dental caries              1.000000  0.999995  ...  0.999947  0.999494
# smoking                    1.000000  0.999995  ...  0.999947  0.999494
#
#                      hemoglobin  Urine protein  serum creatinine       AST  \
# ID                     0.520343       0.520179          0.520248  0.534002
# age                    1.000000       0.999999          1.000000  0.999755
# height(cm)             0.999997       0.999996          0.999996  0.999754
# weight(kg)             0.999999       0.999998          0.999999  0.999768
# waist(cm)              0.999999       0.999999          0.999999  0.999760
# eyesight(left)         1.000000       1.000000          1.000000  0.999739
# eyesight(right)        1.000000       1.000000          1.000000  0.999739
# hearing(left)          1.000000       1.000000          1.000000  0.999735
# hearing(right)         1.000000       1.000000          1.000000  0.999735
# systolic               0.999996       0.999995          0.999995  0.999790
# relaxation             0.999999       0.999998          0.999998  0.999769
# fasting blood sugar    0.999971       0.999970          0.999971  0.999881
# Cholesterol            0.999982       0.999980          0.999981  0.999839
# triglyceride           0.999870       0.999868          0.999869  0.999975
# HDL                    0.999949       0.999947          0.999949  0.999919
# LDL                    0.999499       0.999496          0.999499  0.999960
# hemoglobin             1.000000       1.000000          1.000000  0.999739
# Urine protein          1.000000       1.000000          1.000000  0.999737
# serum creatinine       1.000000       1.000000          1.000000  0.999739
# AST                    0.999739       0.999737          0.999739  1.000000
# ALT                    0.998669       0.998665          0.998670  0.999587
# Gtp                    0.999853       0.999852          0.999854  0.999983
# dental caries          1.000000       1.000000          1.000000  0.999735
# smoking                1.000000       1.000000          1.000000  0.999735
#
#                           ALT       Gtp  dental caries   smoking
# ID                   0.550745  0.530752       0.520132  0.520138
# age                  0.998705  0.999865       0.999999  0.999999
# height(cm)           0.998708  0.999863       0.999996  0.999996
# weight(kg)           0.998736  0.999875       0.999998  0.999998
# waist(cm)            0.998718  0.999868       0.999999  0.999999
# eyesight(left)       0.998668  0.999853       1.000000  1.000000
# eyesight(right)      0.998668  0.999853       1.000000  1.000000
# hearing(left)        0.998661  0.999851       1.000000  1.000000
# hearing(right)       0.998661  0.999851       1.000000  1.000000
# systolic             0.998789  0.999890       0.999995  0.999995
# relaxation           0.998738  0.999875       0.999998  0.999998
# fasting blood sugar  0.999026  0.999952       0.999970  0.999970
# Cholesterol          0.998917  0.999923       0.999980  0.999980
# triglyceride         0.999365  0.999998       0.999867  0.999867
# HDL                  0.999139  0.999975       0.999947  0.999947
# LDL                  0.999798  0.999893       0.999494  0.999494
# hemoglobin           0.998669  0.999853       1.000000  1.000000
# Urine protein        0.998665  0.999852       1.000000  1.000000
# serum creatinine     0.998670  0.999854       1.000000  1.000000
# AST                  0.999587  0.999983       0.999735  0.999735
# ALT                  1.000000  0.999405       0.998661  0.998661
# Gtp                  0.999405  1.000000       0.999851  0.999851
# dental caries        0.998661  0.999851       1.000000  1.000000
# smoking              0.998661  0.999851       1.000000  1.000000
#
# [24 rows x 24 columns]

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr())

# %%
df.columns
# Out:
# Index(['ID', 'gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)',
#        'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)',
#        'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol',
#        'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein',
#        'serum creatinine', 'AST', 'ALT', 'Gtp', 'oral', 'dental caries',
#        'tartar', 'smoking'],
#       dtype='object')

# %%
df=df.drop(['ID'],axis=1)

# %%
df.head()
# Out:
#   gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0      F   40         155          60       81.3             1.2
# 1      F   40         160          60       81.0             0.8
# 2      M   55         170          60       80.0             0.8
# 3      M   40         165          70       88.0             1.5
# 4      F   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  hemoglobin  \
# 0              1.0            1.0             1.0     114.0  ...        12.9
# 1              0.6            1.0             1.0     119.0  ...        12.7
# 2              0.8            1.0             1.0     138.0  ...        15.8
# 3              1.5            1.0             1.0     100.0  ...        14.7
# 4              1.0            1.0             1.0     120.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               0.7  18.0  19.0  27.0     Y              0
# 1            1.0               0.6  22.0  19.0  18.0     Y              0
# 2            1.0               1.0  21.0  16.0  22.0     Y              0
# 3            1.0               1.0  19.0  26.0  18.0     Y              0
# 4            1.0               0.6  16.0  14.0  22.0     Y              0
#
#    tartar  smoking
# 0       Y        0
# 1       Y        0
# 2       N        1
# 3       Y        0
# 4       N        0
#
# [5 rows x 26 columns]

# %%
object_col=[]
num_col=[]
for i in df.columns:
    if df[i].dtype=='object':
        object_col.append(i)
    else:
        num_col.append(i)

# %%
object_col
# Out:
# ['gender', 'oral', 'tartar']

# %%
num_col
# Out:
# ['age',
#  'height(cm)',
#  'weight(kg)',
#  'waist(cm)',
#  'eyesight(left)',
#  'eyesight(right)',
#  'hearing(left)',
#  'hearing(right)',
#  'systolic',
#  'relaxation',
#  'fasting blood sugar',
#  'Cholesterol',
#  'triglyceride',
#  'HDL',
#  'LDL',
#  'hemoglobin',
#  'Urine protein',
#  'serum creatinine',
#  'AST',
#  'ALT',
#  'Gtp',
#  'dental caries',
#  'smoking']

# %%
le=LabelEncoder()

# %%
df_col=('gender', 'oral', 'tartar')

# %%
for i in df_col:
    df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0       0   40         155          60       81.3             1.2
# 1       0   40         160          60       81.0             0.8
# 2       1   55         170          60       80.0             0.8
# 3       1   40         165          70       88.0             1.5
# 4       0   40         155          60       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  hemoglobin  \
# 0              1.0            1.0             1.0     114.0  ...        12.9
# 1              0.6            1.0             1.0     119.0  ...        12.7
# 2              0.8            1.0             1.0     138.0  ...        15.8
# 3              1.5            1.0             1.0     100.0  ...        14.7
# 4              1.0            1.0             1.0     120.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               0.7  18.0  19.0  27.0     0              0
# 1            1.0               0.6  22.0  19.0  18.0     0              0
# 2            1.0               1.0  21.0  16.0  22.0     0              0
# 3            1.0               1.0  19.0  26.0  18.0     0              0
# 4            1.0               0.6  16.0  14.0  22.0     0              0
#
#    tartar  smoking
# 0       1        0
# 1       1        0
# 2       0        1
# 3       1        0
# 4       0        0
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)',
#        'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)',
#        'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol',
#        'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein',
#        'serum creatinine', 'AST', 'ALT', 'Gtp', 'oral', 'dental caries',
#        'tartar', 'smoking'],
#       dtype='object')

# %%
df.shape
# Out:
# (55692, 26)

# %%
#Removal of outlier:

df1 = df.copy()

#features1 = [i for i in features if i not in ['CHAS','RAD']]
features1 = df1

for i in features1:
    Q1 = df1[i].quantile(0.25)
    Q3 = df1[i].quantile(0.75)
    IQR = Q3 - Q1
    df1 = df1[df1[i] <= (Q3+(1.5*IQR))]
    df1 = df1[df1[i] >= (Q1-(1.5*IQR))]
    df1 = df1.reset_index(drop=True)
display(df1.head())
print('\n\033[1mInference:\033[0m\nBefore removal of outliers, The dataset had {} samples.'.format(df.shape[0]))
print('After removal of outliers, The dataset now has {} samples.'.format(df1.shape[0]))
# Out:
#    gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0       0   40         155          60       81.3             1.2
# 1       1   55         170          60       80.0             0.8
# 2       0   40         155          60       86.0             1.0
# 3       1   30         180          75       85.0             1.2
# 4       0   50         150          60       85.0             0.7
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  hemoglobin  \
# 0              1.0            1.0             1.0     114.0  ...        12.9
# 1              0.8            1.0             1.0     138.0  ...        15.8
# 2              1.0            1.0             1.0     120.0  ...        12.5
# 3              1.2            1.0             1.0     128.0  ...        16.2
# 4              0.8            1.0             1.0     115.0  ...        13.7
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               0.7  18.0  19.0  27.0     0              0
# 1            1.0               1.0  21.0  16.0  22.0     0              0
# 2            1.0               0.6  16.0  14.0  22.0     0              0
# 3            1.0               1.2  18.0  27.0  33.0     0              0
# 4            1.0               0.8  31.0  31.0  14.0     0              0
#
#    tartar  smoking
# 0       1        0
# 1       0        1
# 2       0        0
# 3       1        0
# 4       0        0
#
# [5 rows x 26 columns]
# Inference:
# Before removal of outliers, The dataset had 55692 samples.
# After removal of outliers, The dataset now has 24967 samples.

# %%
df1.shape
# Out:
# (24967, 26)

# %%
#Removal of outlier:

df2 = df1.copy()

#features1 = [i for i in features if i not in ['CHAS','RAD']]
features1 = df1

for i in features1:
    Q1 = df2[i].quantile(0.25)
    Q3 = df2[i].quantile(0.75)
    IQR = Q3 - Q1
    df2 = df2[df2[i] <= (Q3+(1.5*IQR))]
    df2= df2[df2[i] >= (Q1-(1.5*IQR))]
    df2 = df2.reset_index(drop=True)
display(df1.head())
print('\n\033[1mInference:\033[0m\nBefore removal of outliers, The dataset had {} samples.'.format(df1.shape[0]))
print('After removal of outliers, The dataset now has {} samples.'.format(df2.shape[0]))
# Out:
#    gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0       0   40         155          60       81.3             1.2
# 1       1   55         170          60       80.0             0.8
# 2       0   40         155          60       86.0             1.0
# 3       1   30         180          75       85.0             1.2
# 4       0   50         150          60       85.0             0.7
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  hemoglobin  \
# 0              1.0            1.0             1.0     114.0  ...        12.9
# 1              0.8            1.0             1.0     138.0  ...        15.8
# 2              1.0            1.0             1.0     120.0  ...        12.5
# 3              1.2            1.0             1.0     128.0  ...        16.2
# 4              0.8            1.0             1.0     115.0  ...        13.7
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               0.7  18.0  19.0  27.0     0              0
# 1            1.0               1.0  21.0  16.0  22.0     0              0
# 2            1.0               0.6  16.0  14.0  22.0     0              0
# 3            1.0               1.2  18.0  27.0  33.0     0              0
# 4            1.0               0.8  31.0  31.0  14.0     0              0
#
#    tartar  smoking
# 0       1        0
# 1       0        1
# 2       0        0
# 3       1        0
# 4       0        0
#
# [5 rows x 26 columns]
# Inference:
# Before removal of outliers, The dataset had 24967 samples.
# After removal of outliers, The dataset now has 20245 samples.

# %%
df2.shape
# Out:
# (20245, 26)

# %%
df2.isnull().sum()
# Out:
# gender                 0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# oral                   0
# dental caries          0
# tartar                 0
# smoking                0
# dtype: int64

# %%
for i  in df.columns:
    print(f'unique values in column "{i}" is\n {df[i].value_counts()}')
    print('-------------------------------------------------')
# Out:
# unique values in column "gender" is
#  1    35401
# 0    20291
# Name: gender, dtype: int64
# -------------------------------------------------
# unique values in column "age" is
#  40    15181
# 45     7037
# 60     6167
# 50     5549
# 55     5020
# 35     4480
# 30     4056
# 25     3525
# 20     1605
# 65     1336
# 70      827
# 75      614
# 80      280
# 85       15
# Name: age, dtype: int64
# -------------------------------------------------
# unique values in column "height(cm)" is
#  170    11381
# 165     9949
# 160     8919
# 175     8009
# 155     7627
# 150     4492
# 180     3149
# 145     1236
# 185      681
# 140      205
# 190       37
# 135        6
# 130        1
# Name: height(cm), dtype: int64
# -------------------------------------------------
# unique values in column "weight(kg)" is
#  65     8196
# 60     8139
# 70     7722
# 55     7326
# 75     6088
# 50     5564
# 80     4117
# 85     2529
# 45     2370
# 90     1477
# 95      816
# 40      468
# 100     436
# 105     200
# 110     113
# 115      49
# 35       39
# 120      23
# 125       8
# 30        7
# 130       4
# 135       1
# Name: weight(kg), dtype: int64
# -------------------------------------------------
# unique values in column "waist(cm)" is
#  80.0     1917
# 82.0     1775
# 81.0     1737
# 84.0     1695
# 78.0     1667
#          ...
# 64.4        1
# 107.7       1
# 111.2       1
# 111.3       1
# 113.4       1
# Name: waist(cm), Length: 566, dtype: int64
# -------------------------------------------------
# unique values in column "eyesight(left)" is
#  1.2    12746
# 1.0    12217
# 1.5     7825
# 0.8     5267
# 0.9     5125
# 0.7     4445
# 0.6     2508
# 0.5     2113
# 0.4     1218
# 0.3      881
# 0.2      464
# 2.0      401
# 0.1      354
# 9.9       92
# 1.6       20
# 1.3       10
# 1.1        3
# 1.9        2
# 1.8        1
# Name: eyesight(left), dtype: int64
# -------------------------------------------------
# unique values in column "eyesight(right)" is
#  1.2    12539
# 1.0    12498
# 1.5     7536
# 0.8     5418
# 0.9     5277
# 0.7     4325
# 0.6     2402
# 0.5     2160
# 0.4     1309
# 0.3      842
# 0.2      522
# 2.0      377
# 0.1      366
# 9.9       92
# 1.6       20
# 1.3        7
# 1.1        2
# Name: eyesight(right), dtype: int64
# -------------------------------------------------
# unique values in column "hearing(left)" is
#  1.0    54267
# 2.0     1425
# Name: hearing(left), dtype: int64
# -------------------------------------------------
# unique values in column "hearing(right)" is
#  1.0    54236
# 2.0     1456
# Name: hearing(right), dtype: int64
# -------------------------------------------------
# unique values in column "systolic" is
#  110.0    3490
# 120.0    3427
# 130.0    3273
# 118.0    2992
# 124.0    1543
#          ...
# 233.0       1
# 191.0       1
# 223.0       1
# 189.0       1
# 71.0        1
# Name: systolic, Length: 130, dtype: int64
# -------------------------------------------------
# unique values in column "relaxation" is
#  80.0     5435
# 70.0     5226
# 78.0     3183
# 60.0     2182
# 72.0     2159
#          ...
# 129.0       1
# 124.0       1
# 119.0       1
# 127.0       1
# 137.0       1
# Name: relaxation, Length: 95, dtype: int64
# -------------------------------------------------
# unique values in column "fasting blood sugar" is
#  94.0     2213
# 97.0     2151
# 93.0     2141
# 92.0     2133
# 95.0     2132
#          ...
# 269.0       1
# 423.0       1
# 326.0       1
# 365.0       1
# 341.0       1
# Name: fasting blood sugar, Length: 276, dtype: int64
# -------------------------------------------------
# unique values in column "Cholesterol" is
#  199.0    696
# 192.0    664
# 198.0    654
# 187.0    650
# 197.0    639
#         ...
# 406.0      1
# 364.0      1
# 87.0       1
# 375.0      1
# 419.0      1
# Name: Cholesterol, Length: 286, dtype: int64
# -------------------------------------------------
# unique values in column "triglyceride" is
#  71.0     524
# 82.0     498
# 79.0     494
# 83.0     486
# 85.0     477
#         ...
# 8.0        1
# 15.0       1
# 405.0      1
# 999.0      1
# 548.0      1
# Name: triglyceride, Length: 390, dtype: int64
# -------------------------------------------------
# unique values in column "HDL" is
#  54.0     1686
# 51.0     1678
# 50.0     1657
# 56.0     1643
# 53.0     1640
#          ...
# 144.0       1
# 618.0       1
# 359.0       1
# 155.0       1
# 11.0        1
# Name: HDL, Length: 126, dtype: int64
# -------------------------------------------------
# unique values in column "LDL" is
#  110.0    727
# 112.0    726
# 107.0    703
# 121.0    702
# 106.0    694
#         ...
# 780.0      1
# 271.0      1
# 325.0      1
# 252.0      1
# 18.0       1
# Name: LDL, Length: 289, dtype: int64
# -------------------------------------------------
# unique values in column "hemoglobin" is
#  15.0    1523
# 15.4    1522
# 15.6    1497
# 15.3    1492
# 15.5    1475
#         ...
# 6.8        1
# 19.5       1
# 19.4       1
# 6.2        1
# 6.1        1
# Name: hemoglobin, Length: 145, dtype: int64
# -------------------------------------------------
# unique values in column "Urine protein" is
#  1.0    52599
# 2.0     1795
# 3.0      940
# 4.0      260
# 5.0       88
# 6.0       10
# Name: Urine protein, dtype: int64
# -------------------------------------------------
# unique values in column "serum creatinine" is
#  0.9     11293
# 0.8     10508
# 1.0      9718
# 0.7      7465
# 1.1      6161
# 0.6      4493
# 1.2      2907
# 0.5      1493
# 1.3       898
# 1.4       292
# 0.4       206
# 1.5       102
# 1.6        38
# 0.1        23
# 1.8        16
# 0.3        15
# 1.7        15
# 1.9         9
# 2.0         9
# 2.1         4
# 2.5         3
# 2.6         3
# 0.2         2
# 2.2         2
# 7.4         2
# 3.4         2
# 10.0        2
# 9.9         1
# 5.0         1
# 11.6        1
# 3.2         1
# 5.9         1
# 3.3         1
# 2.3         1
# 6.4         1
# 10.3        1
# 3.0         1
# 7.5         1
# Name: serum creatinine, dtype: int64
# -------------------------------------------------
# unique values in column "AST" is
#  20.0     3817
# 21.0     3748
# 22.0     3609
# 19.0     3575
# 23.0     3375
#          ...
# 189.0       1
# 276.0       1
# 315.0       1
# 132.0       1
# 131.0       1
# Name: AST, Length: 219, dtype: int64
# -------------------------------------------------
# unique values in column "ALT" is
#  15.0     2744
# 16.0     2621
# 17.0     2621
# 14.0     2576
# 18.0     2544
#          ...
# 275.0       1
# 185.0       1
# 271.0       1
# 270.0       1
# 180.0       1
# Name: ALT, Length: 245, dtype: int64
# -------------------------------------------------
# unique values in column "Gtp" is
#  15.0     2117
# 16.0     2109
# 14.0     2085
# 17.0     2055
# 18.0     2013
#          ...
# 573.0       1
# 449.0       1
# 770.0       1
# 311.0       1
# 550.0       1
# Name: Gtp, Length: 488, dtype: int64
# -------------------------------------------------
# unique values in column "oral" is
#  0    55692
# Name: oral, dtype: int64
# -------------------------------------------------
# unique values in column "dental caries" is
#  0    43811
# 1    11881
# Name: dental caries, dtype: int64
# -------------------------------------------------
# unique values in column "tartar" is
#  1    30940
# 0    24752
# Name: tartar, dtype: int64
# -------------------------------------------------
# unique values in column "smoking" is
#  0    35237
# 1    20455
# Name: smoking, dtype: int64
# -------------------------------------------------

# %%
df.min()
# Out:
# gender                   0.0
# age                     20.0
# height(cm)             130.0
# weight(kg)              30.0
# waist(cm)               51.0
# eyesight(left)           0.1
# eyesight(right)          0.1
# hearing(left)            1.0
# hearing(right)           1.0
# systolic                71.0
# relaxation              40.0
# fasting blood sugar     46.0
# Cholesterol             55.0
# triglyceride             8.0
# HDL                      4.0
# LDL                      1.0
# hemoglobin               4.9
# Urine protein            1.0
# serum creatinine         0.1
# AST                      6.0
# ALT                      1.0
# Gtp                      1.0
# oral                     0.0
# dental caries            0.0
# tartar                   0.0
# smoking                  0.0
# dtype: float64

# %%
df.max()
# Out:
# gender                    1.0
# age                      85.0
# height(cm)              190.0
# weight(kg)              135.0
# waist(cm)               129.0
# eyesight(left)            9.9
# eyesight(right)           9.9
# hearing(left)             2.0
# hearing(right)            2.0
# systolic                240.0
# relaxation              146.0
# fasting blood sugar     505.0
# Cholesterol             445.0
# triglyceride            999.0
# HDL                     618.0
# LDL                    1860.0
# hemoglobin               21.1
# Urine protein             6.0
# serum creatinine         11.6
# AST                    1311.0
# ALT                    2914.0
# Gtp                     999.0
# oral                      0.0
# dental caries             1.0
# tartar                    1.0
# smoking                   1.0
# dtype: float64

# %%
df.skew()
# Out:
# gender                 -0.563789
# age                     0.268053
# height(cm)             -0.142238
# weight(kg)              0.534042
# waist(cm)               0.242390
# eyesight(left)          9.987651
# eyesight(right)        10.059531
# hearing(left)           6.009185
# hearing(right)          5.939591
# systolic                0.469780
# relaxation              0.394602
# fasting blood sugar     4.509412
# Cholesterol             0.392355
# triglyceride            1.313403
# HDL                     1.955282
# LDL                    10.673511
# hemoglobin             -0.655237
# Urine protein           5.625088
# serum creatinine        9.401928
# AST                    25.147528
# ALT                    34.686797
# Gtp                     6.744798
# oral                    0.000000
# dental caries           1.399563
# tartar                 -0.223613
# smoking                 0.550612
# dtype: float64

# %%
x=df2.drop(['gender'],axis='columns')
y=df2.gender.values

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
lo=LogisticRegression()
lo.fit(xtrain,ytrain)
pred_lo=lo.predict(xtest)
accu_lo=accuracy_score(ytest,pred_lo)*100
accu_lo
# Out:
# C:\Users\mdasi\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 89.90780375370431

# %%
print(classification_report(ytest,pred_lo))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      2930
#            1       0.90      0.91      0.90      3144
#
#     accuracy                           0.90      6074
#    macro avg       0.90      0.90      0.90      6074
# weighted avg       0.90      0.90      0.90      6074

# %%
tre=DecisionTreeClassifier()
tre.fit(xtrain,ytrain)
pred_tre=tre.predict(xtest)
accu_tre=accuracy_score(ytest,pred_tre)*100
accu_tre
# Out:
# 96.47678630227198

# %%
print(classification_report(ytest,pred_tre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      2930
#            1       0.96      0.97      0.97      3144
#
#     accuracy                           0.96      6074
#    macro avg       0.96      0.96      0.96      6074
# weighted avg       0.96      0.96      0.96      6074

# %%
kne=KNeighborsClassifier()
kne.fit(xtrain,ytrain)
pred_kne=kne.predict(xtest)
accu_kne=accuracy_score(ytest,pred_kne)*100
accu_kne
# Out:
# 88.45900559762924

# %%
print(classification_report(ytest,pred_kne))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88      2930
#            1       0.89      0.89      0.89      3144
#
#     accuracy                           0.88      6074
#    macro avg       0.88      0.88      0.88      6074
# weighted avg       0.88      0.88      0.88      6074

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada=AdaBoostClassifier()
ada.fit(xtrain,ytrain)
pred_ada=ada.predict(xtest)
accu_ada=accuracy_score(ytest,pred_ada)*100
accu_ada
# Out:
# 97.13533091866974

# %%
print(classification_report(ytest,pred_ada))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2930
#            1       0.98      0.97      0.97      3144
#
#     accuracy                           0.97      6074
#    macro avg       0.97      0.97      0.97      6074
# weighted avg       0.97      0.97      0.97      6074

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag=BaggingClassifier()
bag.fit(xtrain,ytrain)
pred_bag=bag.predict(xtest)
accu_bag=accuracy_score(ytest , pred_bag)*100
accu_bag
# Out:
# 97.36582153440895

# %%
print(classification_report(ytest,pred_bag))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      2930
#            1       0.98      0.97      0.97      3144
#
#     accuracy                           0.97      6074
#    macro avg       0.97      0.97      0.97      6074
# weighted avg       0.97      0.97      0.97      6074

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gau=GaussianNB()
gau.fit(xtrain,ytrain)
pre_gau=gau.predict(xtest)
accu_l=accuracy_score(ytest,pre_gau)*100
accu_l
# Out:
# 95.11030622324662

# %%
print(classification_report(ytest,pre_gau))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95      2930
#            1       0.95      0.96      0.95      3144
#
#     accuracy                           0.95      6074
#    macro avg       0.95      0.95      0.95      6074
# weighted avg       0.95      0.95      0.95      6074

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
etc=ExtraTreesClassifier()
etc.fit(xtrain,ytrain)
pre_etc=etc.predict(xtest)
accu_etc=accuracy_score(ytest,pre_etc)*100
accu_etc
# Out:
# 97.87619361211722

# %%
print(classification_report(ytest,pre_etc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2930
#            1       0.98      0.98      0.98      3144
#
#     accuracy                           0.98      6074
#    macro avg       0.98      0.98      0.98      6074
# weighted avg       0.98      0.98      0.98      6074

# %%
from sklearn.svm import SVC

# %%
svc=SVC()
svc.fit(xtrain,ytrain)
pre_svc=svc.predict(xtest)
accu_svc=accuracy_score(ytest,pre_svc)*100
accu_svc
# Out:
# 92.26210075732631

# %%
print(classification_report(ytest,pre_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      2930
#            1       0.93      0.92      0.92      3144
#
#     accuracy                           0.92      6074
#    macro avg       0.92      0.92      0.92      6074
# weighted avg       0.92      0.92      0.92      6074

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rnd=RandomForestClassifier()
rnd.fit(xtrain,ytrain)
pre_rnd=rnd.predict(xtest)
accu_rnd=accuracy_score(ytest,pre_rnd)*100
accu_rnd
# Out:
# 97.85972999670727

# %%
print(classification_report(ytest,pre_rnd))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      2930
#            1       0.98      0.98      0.98      3144
#
#     accuracy                           0.98      6074
#    macro avg       0.98      0.98      0.98      6074
# weighted avg       0.98      0.98      0.98      6074

# %%
models = pd.DataFrame({
    'Model': ['LogisticRegression','DecisionTreeClassifier','KNeighborsClassifier' , 
             'AdaBoostClassifier','BaggingClassifier','GaussianNB','AdaBoostClassifier','ExtraTreesClassifier','SVM','RandomForestClassifier'],
    'Score': [accu_lo,accu_tre, accu_kne, accu_ada,accu_bag,accu_l,accu_ada,accu_etc,accu_svc,accu_rnd]
})

models.sort_values(by = 'Score', ascending = False)
# Out:
#                     Model      Score
# 7    ExtraTreesClassifier  97.876194
# 9  RandomForestClassifier  97.859730
# 4       BaggingClassifier  97.365822
# 3      AdaBoostClassifier  97.135331
# 6      AdaBoostClassifier  97.135331
# 1  DecisionTreeClassifier  96.476786
# 5              GaussianNB  95.110306
# 8                     SVM  92.262101
# 0      LogisticRegression  89.907804
# 2    KNeighborsClassifier  88.459006

# %%
colors = ["purple", "green", "orange", "magenta","blue","black","red"]

sns.set_style("whitegrid")
plt.figure(figsize=(15,8))
plt.ylabel("Accuracy %")
plt.xlabel("Algorithms")
sns.barplot(x=models['Model'],y=models['Score'], palette=colors )
plt.show()

# %%
df2.head()
# Out:
#    gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0       0   40         155          60       81.3             1.2
# 1       1   55         170          60       80.0             0.8
# 2       0   40         155          60       86.0             1.0
# 3       1   30         180          75       85.0             1.2
# 4       0   50         150          60       85.0             0.7
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  hemoglobin  \
# 0              1.0            1.0             1.0     114.0  ...        12.9
# 1              0.8            1.0             1.0     138.0  ...        15.8
# 2              1.0            1.0             1.0     120.0  ...        12.5
# 3              1.2            1.0             1.0     128.0  ...        16.2
# 4              0.8            1.0             1.0     115.0  ...        13.7
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# 0            1.0               0.7  18.0  19.0  27.0     0              0
# 1            1.0               1.0  21.0  16.0  22.0     0              0
# 2            1.0               0.6  16.0  14.0  22.0     0              0
# 3            1.0               1.2  18.0  27.0  33.0     0              0
# 4            1.0               0.8  31.0  31.0  14.0     0              0
#
#    tartar  smoking
# 0       1        0
# 1       0        1
# 2       0        0
# 3       1        0
# 4       0        0
#
# [5 rows x 26 columns]

# %%
import pickle
